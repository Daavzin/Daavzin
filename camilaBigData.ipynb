# %% [markdown]
# <a href="https://colab.research.google.com/github/Daavzin/Daavzin/blob/main/camilaBigData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-talk')
# Out:
# <ipython-input-4-95b978f010a1>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-talk')

# %%
dados = pd.read_csv('/content/Dados-Pesquisa (1).csv')
# Out:
# <ipython-input-8-a633298dbedc>:1: DtypeWarning: Columns (21,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   dados = pd.read_csv('/content/Dados-Pesquisa (1).csv')

# %%
dados.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# 1                NaN             NaN  ...               NaN
# 2                NaN             NaN  ...               NaN
# 3                NaN             NaN  ...               NaN
# 4                NaN             NaN  ...               NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 0                    NaN                NaN              NaN            NaN
# 1                    NaN                NaN              NaN            1.0
# 2                    NaN                NaN              NaN            NaN
# 3                    NaN                NaN              NaN            NaN
# 4                    NaN                NaN              NaN            NaN
#
#    ResourceW3Schools  ResourceYouTube  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
#                               SchoolDegree              SchoolMajor  \
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN
#
#    StudentDebtOwe
# 0         20000.0
# 1             NaN
# 2             NaN
# 3          7000.0
# 4             NaN
#
# [5 rows x 113 columns]

# %%
dados.head()
dados.tail()
dados.shape
dados.head(1-2)
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0      28.0               0.0             NaN                   NaN
# 1      22.0               0.0             NaN                   NaN
# 2      19.0               0.0             NaN                   NaN
# 3      26.0               0.0             NaN                   NaN
# 4      20.0               0.0             NaN                   NaN
# ...     ...               ...             ...                   ...
# 15614  47.0               0.0             NaN                   NaN
# 15615  39.0               0.0             NaN                   NaN
# 15616  27.0               0.0             NaN                   NaN
# 15617  37.0               0.0             NaN                   NaN
# 15618  26.0               0.0             NaN                   NaN
#
#        BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                    NaN                NaN          NaN                 NaN
# 1                    NaN                NaN          NaN                 NaN
# 2                    NaN                NaN          NaN                 NaN
# 3                    NaN                NaN          NaN                 NaN
# 4                    NaN                NaN          NaN                 NaN
# ...                  ...                ...          ...                 ...
# 15614                NaN                NaN          NaN                 NaN
# 15615                NaN                NaN          NaN                 NaN
# 15616                NaN                NaN          NaN                 NaN
# 15617                NaN                NaN          NaN                 NaN
# 15618                NaN                NaN          NaN                 NaN
#
#        BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                    NaN             NaN  ...               NaN
# 1                    NaN             NaN  ...               NaN
# 2                    NaN             NaN  ...               NaN
# 3                    NaN             NaN  ...               NaN
# 4                    NaN             NaN  ...               NaN
# ...                  ...             ...  ...               ...
# 15614                NaN             NaN  ...               NaN
# 15615                NaN             NaN  ...               NaN
# 15616                NaN             NaN  ...               NaN
# 15617                NaN             NaN  ...               NaN
# 15618                NaN             NaN  ...               NaN
#
#        ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  \
# 0                        NaN                NaN              NaN
# 1                        NaN                NaN              NaN
# 2                        NaN                NaN              NaN
# 3                        NaN                NaN              NaN
# 4                        NaN                NaN              NaN
# ...                      ...                ...              ...
# 15614                    NaN                NaN              NaN
# 15615                    NaN                NaN              NaN
# 15616                    NaN                1.0              NaN
# 15617                    NaN                NaN              NaN
# 15618                    NaN                NaN              NaN
#
#        ResourceUdemy  ResourceW3Schools  ResourceYouTube  \
# 0                NaN                NaN              NaN
# 1                1.0                NaN              NaN
# 2                NaN                NaN              NaN
# 3                NaN                NaN              NaN
# 4                NaN                NaN              NaN
# ...              ...                ...              ...
# 15614            NaN                NaN              NaN
# 15615            1.0                NaN              NaN
# 15616            NaN                NaN              NaN
# 15617            NaN                NaN              NaN
# 15618            1.0                NaN              NaN
#
#                                    SchoolDegree              SchoolMajor  \
# 0                some college credit, no degree                      NaN
# 1                some college credit, no degree                      NaN
# 2       high school diploma or equivalent (GED)                      NaN
# 3                             bachelor's degree  Cinematography And Film
# 4                some college credit, no degree                      NaN
# ...                                         ...                      ...
# 15614  trade, technical, or vocational training                      NaN
# 15615                         bachelor's degree                Chemistry
# 15616                         bachelor's degree   Electrical Engineering
# 15617                         bachelor's degree                Chemistry
# 15618        master's degree (non-professional)                     Math
#
#        StudentDebtOwe
# 0             20000.0
# 1                 NaN
# 2                 NaN
# 3              7000.0
# 4                 NaN
# ...               ...
# 15614             NaN
# 15615             NaN
# 15616             NaN
# 15617             NaN
# 15618             NaN
#
# [15619 rows x 113 columns]

# %%
dados.shape
# Out:
# (15620, 113)

# %%
dados.columns.to_list()
# Out:
# ['Age',
#  'AttendedBootcamp',
#  'BootcampFinish',
#  'BootcampFullJobAfter',
#  'BootcampLoanYesNo',
#  'BootcampMonthsAgo',
#  'BootcampName',
#  'BootcampPostSalary',
#  'BootcampRecommend',
#  'ChildrenNumber',
#  'CityPopulation',
#  'CodeEventBootcamp',
#  'CodeEventCoffee',
#  'CodeEventConferences',
#  'CodeEventDjangoGirls',
#  'CodeEventGameJam',
#  'CodeEventGirlDev',
#  'CodeEventHackathons',
#  'CodeEventMeetup',
#  'CodeEventNodeSchool',
#  'CodeEventNone',
#  'CodeEventOther',
#  'CodeEventRailsBridge',
#  'CodeEventRailsGirls',
#  'CodeEventStartUpWknd',
#  'CodeEventWomenCode',
#  'CodeEventWorkshop',
#  'CommuteTime',
#  'CountryCitizen',
#  'CountryLive',
#  'EmploymentField',
#  'EmploymentFieldOther',
#  'EmploymentStatus',
#  'EmploymentStatusOther',
#  'ExpectedEarning',
#  'FinanciallySupporting',
#  'Gender',
#  'HasChildren',
#  'HasDebt',
#  'HasFinancialDependents',
#  'HasHighSpdInternet',
#  'HasHomeMortgage',
#  'HasServedInMilitary',
#  'HasStudentDebt',
#  'HomeMortgageOwe',
#  'HoursLearning',
#  'ID.x',
#  'ID.y',
#  'Income',
#  'IsEthnicMinority',
#  'IsReceiveDiabilitiesBenefits',
#  'IsSoftwareDev',
#  'IsUnderEmployed',
#  'JobApplyWhen',
#  'JobPref',
#  'JobRelocateYesNo',
#  'JobRoleInterest',
#  'JobRoleInterestOther',
#  'JobWherePref',
#  'LanguageAtHome',
#  'MaritalStatus',
#  'MoneyForLearning',
#  'MonthsProgramming',
#  'NetworkID',
#  'Part1EndTime',
#  'Part1StartTime',
#  'Part2EndTime',
#  'Part2StartTime',
#  'PodcastChangeLog',
#  'PodcastCodeNewbie',
#  'PodcastCodingBlocks',
#  'PodcastDeveloperTea',
#  'PodcastDotNetRocks',
#  'PodcastHanselminutes',
#  'PodcastJSJabber',
#  'PodcastJsAir',
#  'PodcastNone',
#  'PodcastOther',
#  'PodcastProgrammingThrowDown',
#  'PodcastRubyRogues',
#  'PodcastSEDaily',
#  'PodcastShopTalk',
#  'PodcastTalkPython',
#  'PodcastWebAhead',
#  'ResourceBlogs',
#  'ResourceBooks',
#  'ResourceCodeWars',
#  'ResourceCodecademy',
#  'ResourceCoursera',
#  'ResourceDevTips',
#  'ResourceEdX',
#  'ResourceEggHead',
#  'ResourceFCC',
#  'ResourceGoogle',
#  'ResourceHackerRank',
#  'ResourceKhanAcademy',
#  'ResourceLynda',
#  'ResourceMDN',
#  'ResourceOdinProj',
#  'ResourceOther',
#  'ResourcePluralSight',
#  'ResourceReddit',
#  'ResourceSkillCrush',
#  'ResourceSoloLearn',
#  'ResourceStackOverflow',
#  'ResourceTreehouse',
#  'ResourceUdacity',
#  'ResourceUdemy',
#  'ResourceW3Schools',
#  'ResourceYouTube',
#  'SchoolDegree',
#  'SchoolMajor',
#  'StudentDebtOwe']

# %%
df2 = dados.copy()

# %%
dados.isna().sum()
# Out:
# Age                      2007
# AttendedBootcamp          240
# BootcampFinish          14687
# BootcampFullJobAfter    14985
# BootcampLoanYesNo       14686
#                         ...
# ResourceW3Schools       15499
# ResourceYouTube         15499
# SchoolDegree             1941
# SchoolMajor              7170
# StudentDebtOwe          12106
# Length: 113, dtype: int64

# %%
dados.isna().sum().sum()
# Out:
# 1183948

# %%
dados.dropna(subset = ['Age'], inplace= True)

# %%
dados.isna().sum()
# Out:
# Age                         0
# AttendedBootcamp          112
# BootcampFinish          12809
# BootcampFullJobAfter    13068
# BootcampLoanYesNo       12805
#                         ...
# ResourceW3Schools       13508
# ResourceYouTube         13506
# SchoolDegree              113
# SchoolMajor              5265
# StudentDebtOwe          10121
# Length: 113, dtype: int64

# %%
dados.dtypes.value_counts()
# Out:
# float64    85
# object     28
# dtype: int64

# %%
dados = dados[['Age','Gender', 'JobPref',
               'JobRoleInterest',
               'EmploymentField',
               'JobRelocateYesNo',
               'HoursLearning',
               'MoneyForLearning']]
dados
# Out:
#         Age  Gender                          JobPref  \
# 0      28.0    male                       freelance
# 1      22.0    male               work for a startup
# 2      19.0    male          start your own business
# 3      26.0  female               work for a startup
# 4      20.0  female  work for a medium-sized company
# ...     ...     ...                              ...
# 15615  39.0    male          start your own business
# 15616  27.0    male               work for a startup
# 15617  37.0    male                       freelance
# 15618  26.0    male                              NaN
# 15619  22.0  female                       freelance
#
#                  JobRoleInterest                        EmploymentField  \
# 0                            NaN      office and administrative support
# 1        Front-End Web Developer                      food and beverage
# 2                            NaN                                finance
# 3        Front-End Web Developer  arts, entertainment, sports, or media
# 4       Full-Stack Web Developer                              education
# ...                          ...                                    ...
# 15615                        NaN            software development and IT
# 15616    Front-End Web Developer            software development and IT
# 15617                        NaN                                    NaN
# 15618                        NaN                              education
# 15619                        NaN  arts, entertainment, sports, or media
#
#        JobRelocateYesNo  HoursLearning  MoneyForLearning
# 0                   NaN           30.0               0.0
# 1                   1.0           30.0              20.0
# 2                   NaN           20.0              50.0
# 3                   NaN           20.0             100.0
# 4                   1.0           25.0            1300.0
# ...                 ...            ...               ...
# 15615               NaN           40.0               0.0
# 15616               1.0           15.0             100.0
# 15617               NaN           14.0               0.0
# 15618               NaN           10.0              30.0
# 15619               NaN            2.0               0.0
#
# [13613 rows x 8 columns]

# %%
dados = dados.drop_duplicates()

# %%
dados.shape
# Out:
# (12234, 8)

# %%
dados.describe()
# Out:
#                 Age  JobRelocateYesNo  HoursLearning  MoneyForLearning
# count  12234.000000       4669.000000   11807.000000      11643.000000
# mean      29.598823          0.733348      15.713814       1193.690114
# std        9.215518          0.442256      14.548388       4999.765832
# min       10.000000          0.000000       0.000000          0.000000
# 25%       23.000000          0.000000       5.000000          0.000000
# 50%       28.000000          1.000000      10.000000         50.000000
# 75%       34.000000          1.000000      20.000000        400.000000
# max       86.000000          1.000000     100.000000     180000.000000

# %%
dados.describe(include = 'O')
# Out:
#        Gender                          JobPref           JobRoleInterest  \
# count   12194                             9320                      5552
# unique      5                                5                         9
# top      male  work for a medium-sized company  Full-Stack Web Developer
# freq     9360                             2841                      2211
#
#                     EmploymentField
# count                          6683
# unique                           15
# top     software development and IT
# freq                           3473

# %%
dados.loc[dados['Age'] > 30]
# Out:
#         Age  Gender                  JobPref JobRoleInterest  \
# 5      34.0    male  start your own business             NaN
# 7      35.0    male               freelance              NaN
# 8      33.0    male                      NaN             NaN
# 9      33.0    male  start your own business             NaN
# 10     57.0    male               freelance              NaN
# ...     ...     ...                      ...             ...
# 15611  37.0    male  start your own business             NaN
# 15612  45.0  female  start your own business             NaN
# 15614  47.0    male               freelance              NaN
# 15615  39.0    male  start your own business             NaN
# 15617  37.0    male               freelance              NaN
#
#                          EmploymentField  JobRelocateYesNo  HoursLearning  \
# 5                                finance               NaN            5.0
# 7      office and administrative support               NaN            NaN
# 8                   software development               NaN            5.0
# 9                                    NaN               NaN           20.0
# 10                                   NaN               NaN            8.0
# ...                                  ...               ...            ...
# 15611        software development and IT               NaN           40.0
# 15612                                NaN               NaN            2.0
# 15614                            finance               NaN            3.0
# 15615        software development and IT               NaN           40.0
# 15617                                NaN               NaN           14.0
#
#        MoneyForLearning
# 5                   0.0
# 7                   0.0
# 8                3000.0
# 9                  30.0
# 10                400.0
# ...                 ...
# 15611             200.0
# 15612             300.0
# 15614               0.0
# 15615               0.0
# 15617               0.0
#
# [4510 rows x 8 columns]

# %%
dados['Age'].unique()
# Out:
# array([28., 22., 19., 26., 20., 34., 23., 35., 33., 57., 27., 47., 37.,
#        31., 29., 30., 32., 25., 44., 21., 24., 18., 39., 41., 43., 36.,
#        40., 38., 16., 46., 15., 14., 50., 49., 45., 55., 51., 17., 53.,
#        52., 48., 56., 42., 54., 58., 65., 59., 75., 61., 80., 62., 60.,
#        66., 12., 11., 13., 63., 64., 70., 73., 69., 71., 68., 86., 10.,
#        67., 72.])

# %%
dados.Age.unique()
# Out:
# array([28., 22., 19., 26., 20., 34., 23., 35., 33., 57., 27., 47., 37.,
#        31., 29., 30., 32., 25., 44., 21., 24., 18., 39., 41., 43., 36.,
#        40., 38., 16., 46., 15., 14., 50., 49., 45., 55., 51., 17., 53.,
#        52., 48., 56., 42., 54., 58., 65., 59., 75., 61., 80., 62., 60.,
#        66., 12., 11., 13., 63., 64., 70., 73., 69., 71., 68., 86., 10.,
#        67., 72.])

# %%
idade = dados.Age

plt.hist(idade, label = "Idades", color= 'lightseagreen')
plt.title("Distribuição por Idade")
plt.xlabel("Idades")
plt.ylabel("Quantidade")
plt.legend()
#
plt.grid(True)
plt.show()

# %%
dados.Gender.value_counts()
# Out:
# male           9360
# female         2697
# genderqueer      65
# agender          36
# trans            36
# Name: Gender, dtype: int64

# %%
dados.Gender.value_counts().sum()
# Out:
# 12194

# %%
tipos_de_genero = pd.DataFrame(dados.Gender.value_counts())

# %%
tipos_de_genero.head()
# Out:
#              Gender
# male           9360
# female         2697
# genderqueer      65
# agender          36
# trans            36
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Gender'].plot(kind='hist', bins=20, title='Gender')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('index').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2['Gender'].plot(kind='line', figsize=(8, 4), title='Gender')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_3['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_3, x='Gender', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
tipos_de_genero.columns.name = 'Tipo'

# %%
tipos_de_genero.head()
# Out:
# Tipo         Gender
# male           9360
# female         2697
# genderqueer      65
# agender          36
# trans            36

# %%
tipos_de_genero.iloc[0]
# Out:
# Tipo
# Gender    9360
# Name: male, dtype: int64

# %%
feminino = tipos_de_genero.iloc[1]
feminino
# Out:
# Tipo
# Gender    2697
# Name: female, dtype: int64

# %%
total_genero = dados.Gender.value_counts().sum()
total_genero
# Out:
# 12194

# %%
fem = (feminino / total_genero * 100)
fem
# Out:
# Tipo
# Gender    22.117435
# Name: female, dtype: float64

# %%
dados.groupby('Gender').mean()
# Out:
# <ipython-input-56-6f95caccf843>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dados.groupby('Gender').mean()
#                    Age  JobRelocateYesNo  HoursLearning  MoneyForLearning
# Gender
# agender      25.277778          0.642857      13.685714       1023.088235
# female       30.797553          0.653043      14.537481       1558.847478
# genderqueer  28.215385          0.684211      14.311475       1600.316667
# male         29.300000          0.758493      16.066402       1083.079552
# trans        30.000000          0.714286      17.828571       3019.588235

# %%
genero = dados.Gender.value_counts()

# %%
plt.pie(genero)
# Out:
# ([<matplotlib.patches.Wedge at 0x7bca4b3a1c30>,
#   <matplotlib.patches.Wedge at 0x7bca4b3a2b90>,
#   <matplotlib.patches.Wedge at 0x7bca4b3a1f30>,
#   <matplotlib.patches.Wedge at 0x7bca4b3a2f20>,
#   <matplotlib.patches.Wedge at 0x7bca4b383850>],
#  [Text(-0.8195924148082909, 0.7336676860736846, ''),
#   Text(0.7931919072339293, -0.7621329269219392, ''),
#   Text(1.09840575279812, -0.0592013700854625, ''),
#   Text(1.0995742196475298, -0.030602867292558702, ''),
#   Text(1.099952689214474, -0.010202033613305905, '')])

# %%
genero = dados.Gender.value_counts()
plt.pie(genero)
plt.legend(dados.Gender.value_counts().index, bbox_to_anchor= (1, 1))
plt.show()
